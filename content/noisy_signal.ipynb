# %% [markdown]
# # Noisy Signals

# %%
import pyodide_kernel
pyodide_kernel.__version__

# %%
import numpy as np
from scipy.fft import fft, ifft, fftshift, fftfreq
import plotly.graph_objects as go

# %%
n_t = np.random.randn(10240)
n_f = fft(n_t)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=np.arange(len(n_t)), y=20*np.log10(np.abs(n_f))))
